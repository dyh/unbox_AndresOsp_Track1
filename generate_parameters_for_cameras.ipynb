# %%
from config import paths, config

from os.path import isfile, join, isdir
import pandas as pd
import numpy as np


from os import listdir

import yaml

# %%
# Configuration
Counter_parameters = {}


Counter_parameters['detection_min_area_val'] = 800
Counter_parameters['tracks_min_area_val'] = 700

Counter_parameters['detection_max_area_val'] = 10000000

Counter_parameters['detection_object_thresh']  = 0.6
Counter_parameters['tracks_object_thresh'] = 0.02

Counter_parameters['detection_nms_thresh'] =  0.25
Counter_parameters['tracks_nms_thresh'] = 0.6

Counter_parameters['detection_ROI_in'] =  0.2
Counter_parameters['tracks_ROI_in'] =  0.1

Counter_parameters['min_length_trajectory'] = 50


# motion model settings
Counter_parameters['motion_model'] = {}
Counter_parameters['motion_model']['enabled'] = True
# average velocity over last n_steps steps
Counter_parameters['motion_model']['n_steps'] = 1
# if true, only model the movement of the bounding box center. If false, width and height are also modeled.
Counter_parameters['motion_model']['center_only'] = True

# %%
path_data     = paths['path_calibrations']

# %%
individual_parameters = True

# %%
cam_name = '1'
path_metadata = join(path_data,cam_name)

if individual_parameters:
    
    Counter_parameters['detection_object_thresh']  = 0.6
    Counter_parameters['detection_nms_thresh']   = 0.15
    Counter_parameters['detection_min_area_val'] = 1100
    Counter_parameters['detection_max_area_val']  = 100000
    Counter_parameters['tracks_object_thresh'] = 0.00001
    Counter_parameters['tracks_nms_thresh']    = 0.5
    Counter_parameters['tracks_min_area_val']  = 900

path_Counter_parameters = join(path_metadata,'Counter_parameters.yml')
with open(path_Counter_parameters, 'w') as outfile:
    yaml.dump(Counter_parameters, outfile)

# %%
cam_name = '2'
path_metadata = join(path_data,cam_name)

if individual_parameters:

    Counter_parameters['detection_object_thresh']  = 0.5
    Counter_parameters['detection_nms_thresh']   = 0.15
    Counter_parameters['detection_min_area_val'] = 1100
    Counter_parameters['detection_max_area_val']  = 120000
    Counter_parameters['tracks_object_thresh'] = 0.00001
    Counter_parameters['tracks_nms_thresh']    = 0.6
    Counter_parameters['tracks_min_area_val']  = 700

path_Counter_parameters = join(path_metadata,'Counter_parameters.yml')
with open(path_Counter_parameters, 'w') as outfile:
    yaml.dump(Counter_parameters, outfile)

# %%
cam_name = '3'
path_metadata = join(path_data,cam_name)

if individual_parameters:

    Counter_parameters['detection_object_thresh']  = 0.5
    Counter_parameters['detection_nms_thresh']   = 0.15
    Counter_parameters['detection_min_area_val'] = 1500
    Counter_parameters['detection_max_area_val']  = 100000
    Counter_parameters['tracks_object_thresh'] = 0.00001
    Counter_parameters['tracks_nms_thresh']    = 0.5
    Counter_parameters['tracks_min_area_val']  = 1200

path_Counter_parameters = join(path_metadata,'Counter_parameters.yml')
with open(path_Counter_parameters, 'w') as outfile:
    yaml.dump(Counter_parameters, outfile)

# %%
cam_name = '4'
path_metadata = join(path_data,cam_name)

if individual_parameters:
    
    Counter_parameters['detection_object_thresh']  = 0.45
    Counter_parameters['detection_nms_thresh']   = 0.2
    Counter_parameters['detection_min_area_val'] = 1000
    Counter_parameters['detection_max_area_val']  = 1700000
    Counter_parameters['tracks_object_thresh'] = 0.00001
    Counter_parameters['tracks_nms_thresh']    = 0.6
    Counter_parameters['tracks_min_area_val']  = 900

path_Counter_parameters = join(path_metadata,'Counter_parameters.yml')
with open(path_Counter_parameters, 'w') as outfile:
    yaml.dump(Counter_parameters, outfile)

# %%
cam_name = '5'
path_metadata = join(path_data,cam_name)

if individual_parameters:
    Counter_parameters['min_length_trajectory'] = 70
    Counter_parameters['detection_object_thresh']  = 0.45
    Counter_parameters['detection_nms_thresh']   = 0.1
    Counter_parameters['detection_min_area_val'] = 600
    Counter_parameters['detection_max_area_val']  = 1750000
    Counter_parameters['tracks_object_thresh'] = 0.00001
    Counter_parameters['tracks_nms_thresh']    = 0.6
    Counter_parameters['tracks_min_area_val']  = 500

path_Counter_parameters = join(path_metadata,'Counter_parameters.yml')
with open(path_Counter_parameters, 'w') as outfile:
    yaml.dump(Counter_parameters, outfile)

# %%
cam_name = '6'
path_metadata = join(path_data,cam_name)

if individual_parameters:
    Counter_parameters['min_length_trajectory'] = 70
    Counter_parameters['detection_object_thresh']  = 0.552094
    Counter_parameters['detection_nms_thresh']   = 0.2
    Counter_parameters['detection_min_area_val'] = 1200
    Counter_parameters['detection_max_area_val']  = 8370000
    Counter_parameters['tracks_object_thresh'] = 0.001669
    Counter_parameters['tracks_nms_thresh']    = 0.5
    Counter_parameters['tracks_min_area_val']  = 1000

path_Counter_parameters = join(path_metadata,'Counter_parameters.yml')
with open(path_Counter_parameters, 'w') as outfile:
    yaml.dump(Counter_parameters, outfile)

# %%
cam_name = '7'
path_metadata = join(path_data,cam_name)

if individual_parameters:
    Counter_parameters['min_length_trajectory'] = 50
    Counter_parameters['detection_object_thresh']  = 0.45
    Counter_parameters['detection_nms_thresh']   = 0.2
    Counter_parameters['detection_min_area_val'] = 900
    Counter_parameters['detection_max_area_val']  = 21000
    Counter_parameters['tracks_object_thresh'] = 0.00001
    Counter_parameters['tracks_nms_thresh']    = 0.5
    Counter_parameters['tracks_min_area_val']  = 719

path_Counter_parameters = join(path_metadata,'Counter_parameters.yml')
with open(path_Counter_parameters, 'w') as outfile:
    yaml.dump(Counter_parameters, outfile)

# %%
cam_name = '8'
path_metadata = join(path_data,cam_name)

if individual_parameters:

    Counter_parameters['detection_object_thresh']  = 0.65
    Counter_parameters['detection_nms_thresh']   = 0.25
    Counter_parameters['detection_min_area_val'] = 2000
    Counter_parameters['detection_max_area_val']  = 1000000
    Counter_parameters['tracks_object_thresh'] = 0.02
    Counter_parameters['tracks_nms_thresh']    = 0.6
    Counter_parameters['tracks_min_area_val']  = 1000


path_Counter_parameters = join(path_metadata,'Counter_parameters.yml')
with open(path_Counter_parameters, 'w') as outfile:
    yaml.dump(Counter_parameters, outfile)

# %%
cam_name = '9'
path_metadata = join(path_data,cam_name)

if individual_parameters:
    Counter_parameters['min_length_trajectory'] = 90
    Counter_parameters['detection_object_thresh']  = 0.65
    Counter_parameters['detection_nms_thresh']   = 0.25
    Counter_parameters['detection_min_area_val'] = 1500
    Counter_parameters['detection_max_area_val']  = 1000000
    Counter_parameters['tracks_object_thresh'] = 0.02
    Counter_parameters['tracks_nms_thresh']    = 0.6
    Counter_parameters['tracks_min_area_val']  = 1000

path_Counter_parameters = join(path_metadata,'Counter_parameters.yml')
with open(path_Counter_parameters, 'w') as outfile:
    yaml.dump(Counter_parameters, outfile)

# %%
cam_name = '10'
path_metadata = join(path_data,cam_name)

if individual_parameters:
    Counter_parameters['min_length_trajectory'] = 90
    Counter_parameters['detection_object_thresh']  = 0.65
    Counter_parameters['detection_nms_thresh']   = 0.25
    Counter_parameters['detection_min_area_val'] = 2000
    Counter_parameters['detection_max_area_val']  = 1000000
    Counter_parameters['tracks_object_thresh'] = 0.02
    Counter_parameters['tracks_nms_thresh']    = 0.6
    Counter_parameters['tracks_min_area_val']  = 1500

path_Counter_parameters = join(path_metadata,'Counter_parameters.yml')
with open(path_Counter_parameters, 'w') as outfile:
    yaml.dump(Counter_parameters, outfile)

# %%
cam_name = '11'
path_metadata = join(path_data,cam_name)

if individual_parameters:
    Counter_parameters['min_length_trajectory'] = 90
    Counter_parameters['detection_object_thresh']  = 0.65
    Counter_parameters['detection_nms_thresh']   = 0.25
    Counter_parameters['detection_min_area_val'] = 1300
    Counter_parameters['detection_max_area_val']  = 1000000
    Counter_parameters['tracks_object_thresh'] = 0.005
    Counter_parameters['tracks_nms_thresh']    = 0.7
    Counter_parameters['tracks_min_area_val']  = 1000

path_Counter_parameters = join(path_metadata,'Counter_parameters.yml')
with open(path_Counter_parameters, 'w') as outfile:
    yaml.dump(Counter_parameters, outfile)

# %%
cam_name = '12'
path_metadata = join(path_data,cam_name)

if individual_parameters:
    Counter_parameters['min_length_trajectory'] = 90
    Counter_parameters['detection_object_thresh']  = 0.65
    Counter_parameters['detection_nms_thresh']   = 0.25
    Counter_parameters['detection_min_area_val'] = 1300
    Counter_parameters['detection_max_area_val']  = 1000000
    Counter_parameters['tracks_object_thresh'] = 0.02
    Counter_parameters['tracks_nms_thresh']    = 0.6
    Counter_parameters['tracks_min_area_val']  = 1000

path_Counter_parameters = join(path_metadata,'Counter_parameters.yml')
with open(path_Counter_parameters, 'w') as outfile:
    yaml.dump(Counter_parameters, outfile)

# %%
cam_name = '13'
path_metadata = join(path_data,cam_name)

if individual_parameters:
    Counter_parameters['min_length_trajectory'] = 90
    Counter_parameters['detection_object_thresh']  = 0.65
    Counter_parameters['detection_nms_thresh']   = 0.25
    Counter_parameters['detection_min_area_val'] = 1300
    Counter_parameters['detection_max_area_val']  = 1000000
    Counter_parameters['tracks_object_thresh'] = 0.02
    Counter_parameters['tracks_nms_thresh']    = 0.6
    Counter_parameters['tracks_min_area_val']  = 1000

path_Counter_parameters = join(path_metadata,'Counter_parameters.yml')
with open(path_Counter_parameters, 'w') as outfile:
    yaml.dump(Counter_parameters, outfile)

# %%
cam_name = '14'
path_metadata = join(path_data,cam_name)

if individual_parameters:
    Counter_parameters['min_length_trajectory'] = 90
    Counter_parameters['detection_object_thresh']  = 0.65
    Counter_parameters['detection_nms_thresh']   = 0.25
    Counter_parameters['detection_min_area_val'] = 1300
    Counter_parameters['detection_max_area_val']  = 1000000
    Counter_parameters['tracks_object_thresh'] = 0.02
    Counter_parameters['tracks_nms_thresh']    = 0.6
    Counter_parameters['tracks_min_area_val']  = 1000

path_Counter_parameters = join(path_metadata,'Counter_parameters.yml')
with open(path_Counter_parameters, 'w') as outfile:
    yaml.dump(Counter_parameters, outfile)

# %%
cam_name = '15'
path_metadata = join(path_data,cam_name)

if individual_parameters:
    Counter_parameters['min_length_trajectory'] = 90
    Counter_parameters['detection_object_thresh']  = 0.65
    Counter_parameters['detection_nms_thresh']   = 0.25
    Counter_parameters['detection_min_area_val'] = 1300
    Counter_parameters['detection_max_area_val']  = 1000000
    Counter_parameters['tracks_object_thresh'] = 0.02
    Counter_parameters['tracks_nms_thresh']    = 0.6
    Counter_parameters['tracks_min_area_val']  = 1000

path_Counter_parameters = join(path_metadata,'Counter_parameters.yml')
with open(path_Counter_parameters, 'w') as outfile:
    yaml.dump(Counter_parameters, outfile)

# %%
cam_name = '16'
path_metadata = join(path_data,cam_name)

if individual_parameters:
    Counter_parameters['min_length_trajectory'] = 90
    Counter_parameters['detection_object_thresh']  = 0.65
    Counter_parameters['detection_nms_thresh']   = 0.25
    Counter_parameters['detection_min_area_val'] = 1300
    Counter_parameters['detection_max_area_val']  = 1000000
    Counter_parameters['tracks_object_thresh'] = 0.02
    Counter_parameters['tracks_nms_thresh']    = 0.6
    Counter_parameters['tracks_min_area_val']  = 1000

path_Counter_parameters = join(path_metadata,'Counter_parameters.yml')
with open(path_Counter_parameters, 'w') as outfile:
    yaml.dump(Counter_parameters, outfile)

# %%
cam_name = '17'
path_metadata = join(path_data,cam_name)

if individual_parameters:
    Counter_parameters['min_length_trajectory'] = 90
    Counter_parameters['detection_object_thresh']  = 0.65
    Counter_parameters['detection_nms_thresh']   = 0.25
    Counter_parameters['detection_min_area_val'] = 1300
    Counter_parameters['detection_max_area_val']  = 1000000
    Counter_parameters['tracks_object_thresh'] = 0.02
    Counter_parameters['tracks_nms_thresh']    = 0.6
    Counter_parameters['tracks_min_area_val']  = 1000

path_Counter_parameters = join(path_metadata,'Counter_parameters.yml')
with open(path_Counter_parameters, 'w') as outfile:
    yaml.dump(Counter_parameters, outfile)

# %%
cam_name = '18'
path_metadata = join(path_data,cam_name)

if individual_parameters:
    Counter_parameters['min_length_trajectory'] = 90
    Counter_parameters['detection_object_thresh']  = 0.65
    Counter_parameters['detection_nms_thresh']   = 0.25
    Counter_parameters['detection_min_area_val'] = 1300
    Counter_parameters['detection_max_area_val']  = 1000000
    Counter_parameters['tracks_object_thresh'] = 0.02
    Counter_parameters['tracks_nms_thresh']    = 0.6
    Counter_parameters['tracks_min_area_val']  = 1000

path_Counter_parameters = join(path_metadata,'Counter_parameters.yml')
with open(path_Counter_parameters, 'w') as outfile:
    yaml.dump(Counter_parameters, outfile)

# %%
cam_name = '19'
path_metadata = join(path_data,cam_name)

if individual_parameters:
    Counter_parameters['min_length_trajectory'] = 90
    Counter_parameters['detection_object_thresh']  = 0.65
    Counter_parameters['detection_nms_thresh']   = 0.25
    Counter_parameters['detection_min_area_val'] = 1300
    Counter_parameters['detection_max_area_val']  = 1000000
    Counter_parameters['tracks_object_thresh'] = 0.02
    Counter_parameters['tracks_nms_thresh']    = 0.6
    Counter_parameters['tracks_min_area_val']  = 1000

path_Counter_parameters = join(path_metadata,'Counter_parameters.yml')
with open(path_Counter_parameters, 'w') as outfile:
    yaml.dump(Counter_parameters, outfile)

# %%
cam_name = '20'
path_metadata = join(path_data,cam_name)

if individual_parameters:
    Counter_parameters['min_length_trajectory'] = 90
    Counter_parameters['detection_object_thresh']  = 0.65
    Counter_parameters['detection_nms_thresh']   = 0.25
    Counter_parameters['detection_min_area_val'] = 1300
    Counter_parameters['detection_max_area_val']  = 1000000
    Counter_parameters['tracks_object_thresh'] = 0.02
    Counter_parameters['tracks_nms_thresh']    = 0.6
    Counter_parameters['tracks_min_area_val']  = 1000

path_Counter_parameters = join(path_metadata,'Counter_parameters.yml')
with open(path_Counter_parameters, 'w') as outfile:
    yaml.dump(Counter_parameters, outfile)
